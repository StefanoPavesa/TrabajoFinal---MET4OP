# %%
import pandas as pd

# %%
df = pd.read_csv('circuitos-electorales.csv')

# %%
df
# Out:
#                                                    WKT   ID  CIRCUITO_N  \
# 0    MULTIPOLYGON (((-58.3661871461469 -34.62043128...    1           1
# 1    MULTIPOLYGON (((-58.3773566900831 -34.61744732...    2           2
# 2    MULTIPOLYGON (((-58.3572938809189 -34.59510562...    3           3
# 3    MULTIPOLYGON (((-58.3671229141027 -34.61213671...    4           4
# 4    MULTIPOLYGON (((-58.3835637305124 -34.57823507...    5           5
# ..                                                 ...  ...         ...
# 162  MULTIPOLYGON (((-58.4133289404238 -34.64349004...   57          57
# 163  MULTIPOLYGON (((-58.4752520574717 -34.66896222...   89          89
# 164  MULTIPOLYGON (((-58.464421436223 -34.660057142...   90          90
# 165  MULTIPOLYGON (((-58.4713146924268 -34.63664464...  112         112
# 166  MULTIPOLYGON (((-58.4740963168322 -34.63043218...  111         111
#
#      COMUNA         BARRIO    TOTAL  MASCULINO  FEMENINO     PERIMETRO  \
# ...
