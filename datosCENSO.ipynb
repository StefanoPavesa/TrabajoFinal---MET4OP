# %%
import pandas as pd

# %%
dfC = pd.read_csv('censo2010_circuito.csv')

# %%
dfC
# Out:
#       PROV_  DEPTO_ circuito  NBI_0 Hogares sin NBI  NBI_1 Hogares con NBI  \
# 0         2       1     0001                 4368.0                  345.0
# 1         2       1     0002                 3915.0                  560.0
# 2         2       1     0003                 1248.0                  187.0
# 3         2       1     0004                 1026.0                    4.0
# 4         2       1     0005                 6122.0                 2911.0
# ...     ...     ...      ...                    ...                    ...
# 4056     94      14     0112                  340.0                   41.0
# 4057     94      14     0113                 1123.0                   26.0
# 4058     94      14     0114                    9.0                   32.0
# 4059     94      14     0115                   47.0                   26.0
# 4060     94      14     0117                    4.0                    1.0
#
#       NBI_TOTAL  H07_1 Si  H07_2 No  H07_TOTAL  \
# ...
